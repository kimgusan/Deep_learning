# %%
from preprocess import *

# %%
PATH = 'data_in/ChatBotData.csv_short'
VOCAB_PATH = 'data_in/vocabulary.txt'

# %%
inputs, outputs = load_data(PATH)

# %%
display(inputs, outputs)
# Out:
# ['가끔 궁금해',
#  '가끔 뭐하는지 궁금해',
#  '가끔은 혼자인게 좋다',
#  '가난한 자의 설움',
#  '가만 있어도 땀난다',
#  '가상화폐 쫄딱 망함',
#  '가스불 켜고 나갔어',
#  '가스불 켜놓고 나온거 같아',
#  '가스비 너무 많이 나왔다.',
#  '가스비 비싼데 감기 걸리겠어',
#  '남자친구 교회 데려가고 싶어',
#  '남자친구 또 운동 갔어',
#  '남자친구 생일인데 뭘 줄까',
#  '남자친구 승진 선물로 뭐가 좋을까?',
#  '남자친구 오늘 따라 훈훈해 보인다',
#  '남자친구 오늘 좀 질린다.',
#  '남자친구가 나 안 믿어줘',
#  '남자친구가 너무 바빠',
#  '남자친구가 너무 운동만 해',
#  '남자친구가 너무 잘생겼어']
# ['그 사람도 그럴 거예요.',
#  '그 사람도 그럴 거예요.',
#  '혼자를 즐기세요.',
#  '돈은 다시 들어올 거예요.',
#  '땀을 식혀주세요.',
#  '어서 잊고 새출발 하세요.',
#  '빨리 집에 돌아가서 끄고 나오세요.',
#  '빨리 집에 돌아가서 끄고 나오세요.',
#  '다음 달에는 더 절약해봐요.',
#  '따뜻하게 사세요!',
#  '마음을 열 때까지 설득해보세요.',
#  '운동을 함께 해보세요.',
#  '평소에 필요한 것 생각해보세요.',
#  '평소에 필요했던 게 좋을 것 같아요.',
#  '전생에 나라를 구하셨나요.',
#  '결단은 빠를수록 좋아요.',
#  '거짓말 적당히 하세요.',
#  '너무 집착하지 마세요.',
#  '운동을 함께 해보세요.',
#  '전생에 나라를 구하셨나요.']

# %%
char2idx, idx2char, vocab_size = load_vocabulary(PATH, VOCAB_PATH, tokenize_as_morph=False)

# %%
print(char2idx, idx2char, vocab_size, sep='\n')
# Out:
# {'<PAD>': 0, '<SOS>': 1, '<END>': 2, '<UNK>': 3, '새출발': 4, '많이': 5, '믿어줘': 6, '나': 7, '끄고': 8, '보인다': 9, '감기': 10, '해보세요': 11, '망함': 12, '함께': 13, '운동': 14, '혼자인게': 15, '나오세요': 16, '줄까': 17, '돌아가서': 18, '운동을': 19, '설움': 20, '혼자를': 21, '거예요': 22, '필요한': 23, '뭐가': 24, '전생에': 25, '켜놓고': 26, '자의': 27, '달에는': 28, '생일인데': 29, '뭐하는지': 30, '게': 31, '돈은': 32, '결단은': 33, '또': 34, '궁금해': 35, '절약해봐요': 36, '교회': 37, '식혀주세요': 38, '남자친구가': 39, '집에': 40, '쫄딱': 41, '좋을': 42, '따뜻하게': 43, '빨리': 44, '비싼데': 45, '즐기세요': 46, '걸리겠어': 47, '생각해보세요': 48, '어서': 49, '좋을까': 50, '거짓말': 51, '구하셨나요': 52, '좀': 53, '질린다': 54, '가상화폐': 55, '싶어': 56, '선물로': 57, '운동만': 58, '땀난다': 59, '들어올': 60, '가끔': 61, '때까지': 62, '가끔은': 63, '마세요': 64, '것': 65, '평소에': 66, '좋다': 67, '같아': 68, '하세요': 69, '잘생겼어': 70, '더': 71, '데려가고': 72, '안': 73, '설득해보세요': 74, '가스불': 75, '가난한': 76, '좋아요': 77, '따라': 78, '다음': 79, '집착하지': 80, '가스비': 81, '갔어': 82, '가만': 83, '나갔어': 84, '너무': 85, '그': 86, '사람도': 87, '같아요': 88, '그럴': 89, '오늘': 90, '다시': 91, '남자친구': 92, '나왔다': 93, '적당히': 94, '승진': 95, '열': 96, '훈훈해': 97, '필요했던': 98, '나온거': 99, '있어도': 100, '해': 101, '바빠': 102, '땀을': 103, '뭘': 104, '잊고': 105, '마음을': 106, '빠를수록': 107, '나라를': 108, '켜고': 109, '사세요': 110}
# {0: '<PAD>', 1: '<SOS>', 2: '<END>', 3: '<UNK>', 4: '새출발', 5: '많이', 6: '믿어줘', 7: '나', 8: '끄고', 9: '보인다', 10: '감기', 11: '해보세요', 12: '망함', 13: '함께', 14: '운동', 15: '혼자인게', 16: '나오세요', 17: '줄까', 18: '돌아가서', 19: '운동을', 20: '설움', 21: '혼자를', 22: '거예요', 23: '필요한', 24: '뭐가', 25: '전생에', 26: '켜놓고', 27: '자의', 28: '달에는', 29: '생일인데', 30: '뭐하는지', 31: '게', 32: '돈은', 33: '결단은', 34: '또', 35: '궁금해', 36: '절약해봐요', 37: '교회', 38: '식혀주세요', 39: '남자친구가', 40: '집에', 41: '쫄딱', 42: '좋을', 43: '따뜻하게', 44: '빨리', 45: '비싼데', 46: '즐기세요', 47: '걸리겠어', 48: '생각해보세요', 49: '어서', 50: '좋을까', 51: '거짓말', 52: '구하셨나요', 53: '좀', 54: '질린다', 55: '가상화폐', 56: '싶어', 57: '선물로', 58: '운동만', 59: '땀난다', 60: '들어올', 61: '가끔', 62: '때까지', 63: '가끔은', 64: '마세요', 65: '것', 66: '평소에', 67: '좋다', 68: '같아', 69: '하세요', 70: '잘생겼어', 71: '더', 72: '데려가고', 73: '안', 74: '설득해보세요', 75: '가스불', 76: '가난한', 77: '좋아요', 78: '따라', 79: '다음', 80: '집착하지', 81: '가스비', 82: '갔어', 83: '가만', 84: '나갔어', 85: '너무', 86: '그', 87: '사람도', 88: '같아요', 89: '그럴', 90: '오늘', 91: '다시', 92: '남자친구', 93: '나왔다', 94: '적당히', 95: '승진', 96: '열', 97: '훈훈해', 98: '필요했던', 99: '나온거', 100: '있어도', 101: '해', 102: '바빠', 103: '땀을', 104: '뭘', 105: '잊고', 106: '마음을', 107: '빠를수록', 108: '나라를', 109: '켜고', 110: '사세요'}
# 111

# %%
index_inputs, input_seq_len = enc_processing(inputs, char2idx, tokenize_as_morph=False)
index_outputs, output_seq_len = dec_output_processing(outputs, char2idx, tokenize_as_morph=False)
index_targets = dec_target_processing(outputs, char2idx, tokenize_as_morph=False)

# %%
data_configs = {}
data_configs['char2idx'] = char2idx
data_configs['idx2char'] = idx2char
data_configs['vocab_size'] = vocab_size
data_configs['pad_symbol'] = PAD
data_configs['std_symbol'] = STD
data_configs['end_symbol'] = END
data_configs['unk_symbol'] = UNK
print(data_configs)
# Out:
# {'char2idx': {'<PAD>': 0, '<SOS>': 1, '<END>': 2, '<UNK>': 3, '새출발': 4, '많이': 5, '믿어줘': 6, '나': 7, '끄고': 8, '보인다': 9, '감기': 10, '해보세요': 11, '망함': 12, '함께': 13, '운동': 14, '혼자인게': 15, '나오세요': 16, '줄까': 17, '돌아가서': 18, '운동을': 19, '설움': 20, '혼자를': 21, '거예요': 22, '필요한': 23, '뭐가': 24, '전생에': 25, '켜놓고': 26, '자의': 27, '달에는': 28, '생일인데': 29, '뭐하는지': 30, '게': 31, '돈은': 32, '결단은': 33, '또': 34, '궁금해': 35, '절약해봐요': 36, '교회': 37, '식혀주세요': 38, '남자친구가': 39, '집에': 40, '쫄딱': 41, '좋을': 42, '따뜻하게': 43, '빨리': 44, '비싼데': 45, '즐기세요': 46, '걸리겠어': 47, '생각해보세요': 48, '어서': 49, '좋을까': 50, '거짓말': 51, '구하셨나요': 52, '좀': 53, '질린다': 54, '가상화폐': 55, '싶어': 56, '선물로': 57, '운동만': 58, '땀난다': 59, '들어올': 60, '가끔': 61, '때까지': 62, '가끔은': 63, '마세요': 64, '것': 65, '평소에': 66, '좋다': 67, '같아': 68, '하세요': 69, '잘생겼어': 70, '더': 71, '데려가고': 72, '안': 73, '설득해보세요': 74, '가스불': 75, '가난한': 76, '좋아요': 77, '따라': 78, '다음': 79, '집착하지': 80, '가스비': 81, '갔어': 82, '가만': 83, '나갔어': 84, '너무': 85, '그': 86, '사람도': 87, '같아요': 88, '그럴': 89, '오늘': 90, '다시': 91, '남자친구': 92, '나왔다': 93, '적당히': 94, '승진': 95, '열': 96, '훈훈해': 97, '필요했던': 98, '나온거': 99, '있어도': 100, '해': 101, '바빠': 102, '땀을': 103, '뭘': 104, '잊고': 105, '마음을': 106, '빠를수록': 107, '나라를': 108, '켜고': 109, '사세요': 110}, 'idx2char': {0: '<PAD>', 1: '<SOS>', 2: '<END>', 3: '<UNK>', 4: '새출발', 5: '많이', 6: '믿어줘', 7: '나', 8: '끄고', 9: '보인다', 10: '감기', 11: '해보세요', 12: '망함', 13: '함께', 14: '운동', 15: '혼자인게', 16: '나오세요', 17: '줄까', 18: '돌아가서', 19: '운동을', 20: '설움', 21: '혼자를', 22: '거예요', 23: '필요한', 24: '뭐가', 25: '전생에', 26: '켜놓고', 27: '자의', 28: '달에는', 29: '생일인데', 30: '뭐하는지', 31: '게', 32: '돈은', 33: '결단은', 34: '또', 35: '궁금해', 36: '절약해봐요', 37: '교회', 38: '식혀주세요', 39: '남자친구가', 40: '집에', 41: '쫄딱', 42: '좋을', 43: '따뜻하게', 44: '빨리', 45: '비싼데', 46: '즐기세요', 47: '걸리겠어', 48: '생각해보세요', 49: '어서', 50: '좋을까', 51: '거짓말', 52: '구하셨나요', 53: '좀', 54: '질린다', 55: '가상화폐', 56: '싶어', 57: '선물로', 58: '운동만', 59: '땀난다', 60: '들어올', 61: '가끔', 62: '때까지', 63: '가끔은', 64: '마세요', 65: '것', 66: '평소에', 67: '좋다', 68: '같아', 69: '하세요', 70: '잘생겼어', 71: '더', 72: '데려가고', 73: '안', 74: '설득해보세요', 75: '가스불', 76: '가난한', 77: '좋아요', 78: '따라', 79: '다음', 80: '집착하지', 81: '가스비', 82: '갔어', 83: '가만', 84: '나갔어', 85: '너무', 86: '그', 87: '사람도', 88: '같아요', 89: '그럴', 90: '오늘', 91: '다시', 92: '남자친구', 93: '나왔다', 94: '적당히', 95: '승진', 96: '열', 97: '훈훈해', 98: '필요했던', 99: '나온거', 100: '있어도', 101: '해', 102: '바빠', 103: '땀을', 104: '뭘', 105: '잊고', 106: '마음을', 107: '빠를수록', 108: '나라를', 109: '켜고', 110: '사세요'}, 'vocab_size': 111, 'pad_symbol': '<PAD>', 'std_symbol': '<SOS>', 'end_symbol': '<END>', 'unk_symbol': '<UNK>'}

# %%
DATA_IN_PATH = './data_in/'
TRAIN_INPUTS = 'train_inputs.npy'
TRAIN_OUTPUTS = 'train_outputs.npy'
TRAIN_TARGETS = 'train_targets.npy'
DATA_CONFIGS = 'data_configs.json'

np.save(open(DATA_IN_PATH + TRAIN_INPUTS, 'wb'), index_inputs)
np.save(open(DATA_IN_PATH + TRAIN_OUTPUTS, 'wb'), index_outputs)
np.save(open(DATA_IN_PATH + TRAIN_TARGETS, 'wb'), index_targets)

json.dump(data_configs, open(DATA_IN_PATH + DATA_CONFIGS, 'w'))

# %%
char2idx
# Out:
# {'<PAD>': 0,
#  '<SOS>': 1,
#  '<END>': 2,
#  '<UNK>': 3,
#  '새출발': 4,
#  '많이': 5,
#  '믿어줘': 6,
#  '나': 7,
#  '끄고': 8,
#  '보인다': 9,
#  '감기': 10,
#  '해보세요': 11,
#  '망함': 12,
#  '함께': 13,
#  '운동': 14,
#  '혼자인게': 15,
#  '나오세요': 16,
#  '줄까': 17,
#  '돌아가서': 18,
#  '운동을': 19,
#  '설움': 20,
#  '혼자를': 21,
#  '거예요': 22,
#  '필요한': 23,
#  '뭐가': 24,
#  '전생에': 25,
#  '켜놓고': 26,
#  '자의': 27,
#  '달에는': 28,
#  '생일인데': 29,
#  '뭐하는지': 30,
#  '게': 31,
#  '돈은': 32,
#  '결단은': 33,
#  '또': 34,
#  '궁금해': 35,
#  '절약해봐요': 36,
#  '교회': 37,
#  '식혀주세요': 38,
#  '남자친구가': 39,
#  '집에': 40,
#  '쫄딱': 41,
#  '좋을': 42,
#  '따뜻하게': 43,
#  '빨리': 44,
#  '비싼데': 45,
#  '즐기세요': 46,
#  '걸리겠어': 47,
#  '생각해보세요': 48,
#  '어서': 49,
#  '좋을까': 50,
#  '거짓말': 51,
#  '구하셨나요': 52,
#  '좀': 53,
#  '질린다': 54,
#  '가상화폐': 55,
#  '싶어': 56,
#  '선물로': 57,
#  '운동만': 58,
#  '땀난다': 59,
#  '들어올': 60,
#  '가끔': 61,
#  '때까지': 62,
#  '가끔은': 63,
#  '마세요': 64,
#  '것': 65,
#  '평소에': 66,
#  '좋다': 67,
#  '같아': 68,
#  '하세요': 69,
#  '잘생겼어': 70,
#  '더': 71,
#  '데려가고': 72,
#  '안': 73,
#  '설득해보세요': 74,
#  '가스불': 75,
#  '가난한': 76,
#  '좋아요': 77,
#  '따라': 78,
#  '다음': 79,
#  '집착하지': 80,
#  '가스비': 81,
#  '갔어': 82,
#  '가만': 83,
#  '나갔어': 84,
#  '너무': 85,
#  '그': 86,
#  '사람도': 87,
#  '같아요': 88,
#  '그럴': 89,
#  '오늘': 90,
#  '다시': 91,
#  '남자친구': 92,
#  '나왔다': 93,
#  '적당히': 94,
#  '승진': 95,
#  '열': 96,
#  '훈훈해': 97,
#  '필요했던': 98,
#  '나온거': 99,
#  '있어도': 100,
#  '해': 101,
#  '바빠': 102,
#  '땀을': 103,
#  '뭘': 104,
#  '잊고': 105,
#  '마음을': 106,
#  '빠를수록': 107,
#  '나라를': 108,
#  '켜고': 109,
#  '사세요': 110}

# %%
idx2char
# Out:
# {0: '<PAD>',
#  1: '<SOS>',
#  2: '<END>',
#  3: '<UNK>',
#  4: '새출발',
#  5: '많이',
#  6: '믿어줘',
#  7: '나',
#  8: '끄고',
#  9: '보인다',
#  10: '감기',
#  11: '해보세요',
#  12: '망함',
#  13: '함께',
#  14: '운동',
#  15: '혼자인게',
#  16: '나오세요',
#  17: '줄까',
#  18: '돌아가서',
#  19: '운동을',
#  20: '설움',
#  21: '혼자를',
#  22: '거예요',
#  23: '필요한',
#  24: '뭐가',
#  25: '전생에',
#  26: '켜놓고',
#  27: '자의',
#  28: '달에는',
#  29: '생일인데',
#  30: '뭐하는지',
#  31: '게',
#  32: '돈은',
#  33: '결단은',
#  34: '또',
#  35: '궁금해',
#  36: '절약해봐요',
#  37: '교회',
#  38: '식혀주세요',
#  39: '남자친구가',
#  40: '집에',
#  41: '쫄딱',
#  42: '좋을',
#  43: '따뜻하게',
#  44: '빨리',
#  45: '비싼데',
#  46: '즐기세요',
#  47: '걸리겠어',
#  48: '생각해보세요',
#  49: '어서',
#  50: '좋을까',
#  51: '거짓말',
#  52: '구하셨나요',
#  53: '좀',
#  54: '질린다',
#  55: '가상화폐',
#  56: '싶어',
#  57: '선물로',
#  58: '운동만',
#  59: '땀난다',
#  60: '들어올',
#  61: '가끔',
#  62: '때까지',
#  63: '가끔은',
#  64: '마세요',
#  65: '것',
#  66: '평소에',
#  67: '좋다',
#  68: '같아',
#  69: '하세요',
#  70: '잘생겼어',
#  71: '더',
#  72: '데려가고',
#  73: '안',
#  74: '설득해보세요',
#  75: '가스불',
#  76: '가난한',
#  77: '좋아요',
#  78: '따라',
#  79: '다음',
#  80: '집착하지',
#  81: '가스비',
#  82: '갔어',
#  83: '가만',
#  84: '나갔어',
#  85: '너무',
#  86: '그',
#  87: '사람도',
#  88: '같아요',
#  89: '그럴',
#  90: '오늘',
#  91: '다시',
#  92: '남자친구',
#  93: '나왔다',
#  94: '적당히',
#  95: '승진',
#  96: '열',
#  97: '훈훈해',
#  98: '필요했던',
#  99: '나온거',
#  100: '있어도',
#  101: '해',
#  102: '바빠',
#  103: '땀을',
#  104: '뭘',
#  105: '잊고',
#  106: '마음을',
#  107: '빠를수록',
#  108: '나라를',
#  109: '켜고',
#  110: '사세요'}
